# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = []
lka = []
vis = []

# %%
for i in range(1,16,1):
    data.append(np.load(f'Models/publication/recon_hist_dec_vis/mse normalized/{i}/attack.npy',allow_pickle=True))
    lka.append(np.load(f'Documents/Experiments/lka{i}.npy'))
    vis.append(np.load(f'Documents/Experiments/vis{i}.npy',allow_pickle=True))

# %%
o = list('abcdefg')

# %%
fig,ax = plt.subplots()
ax.plot(data[7],label='Model output')
ax.plot([0.055]*len(data[0]))
ax.plot([0.0615]*len(data[0]))
ax.legend()
path = 'Documents/Experiments/exp3'
#fig.savefig(f'{path}{i}.png' , format = 'png' , dpi=500,bbox_inches = 'tight',pad_inches=0.1)

# %%
b = data[6]

# %%
##b = np.load('d.npy')

# %% [markdown]
# ## Check separability

# %%
fig,ax = plt.subplots()
ax.plot(b)
#ax.plot([0.068]*len(b))
#ax.plot([0.058]*len(b))
plt.axvspan(400, 800, facecolor='#929591', alpha=0.4)
plt.axvspan(2000, 2400, facecolor='#929591', alpha=0.4)

# %%
c = 0
l = []
for i in b:
    c+=1
    if  i > 0.2 :
        l.append(i)

# %%
len(l)
# Out:
# 33

# %%
l = l[0::2]

# %%
upper_ON = max(l[:5])
Lower_ON = min(l[:5])

# %%
(np.array(l) <= upper_ON) == (np.array(l) >= Lower_ON)
# Out:
# array([ True,  True,  True,  True,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
len(l)
# Out:
# 17

# %%
c = 0
l = []
for i in b:
    c+=1
    if  i > 0.2 :
        l.append(i)

# %%
len(l)
# Out:
# 33

# %%
l = l[1::2]

# %%
upper_OFF = max(l[:4])
Lower_OFF = min(l[:4])

# %%
#upper_ON,Lower_ON,upper_OFF,Lower_OFF

# %%
(np.array(l) <= upper_OFF) == (np.array(l) >= Lower_OFF)
# Out:
# array([ True,  True,  True,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False])

# %%
len(l)
# Out:
# 16

# %% [markdown]
# ## Stretch thresholds

# %%
c = 0
l = []
for i in b:
    c+=1
    if  i > 0.2 :
        l.append(i)

# %%
l = l[0::2]

# %%
upper_margin_ON = list(sorted(set((l>upper_ON)* l)))[1]
lower_margin_ON = list(sorted(set((l<Lower_ON)* l),reverse=True))[0]

# %%
upper_margin_ON - upper_ON
# Out:
# 0.0016763508

# %%
Lower_ON - lower_margin_ON
# Out:
# 0.001581341

# %%
upper_ON = (max(l[:5])+ upper_margin_ON)/2
Lower_ON = (min(l[:5])+ lower_margin_ON)/2

# %%
(np.array(l) <= upper_ON) == (np.array(l) >= Lower_ON)
# Out:
# array([ True,  True,  True,  True,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
len(l)
# Out:
# 17

# %%
c = 0
l = []
for i in b:
    c+=1
    if  i >0.2 :
        l.append(i)

# %%
len(l)
# Out:
# 33

# %%
l = l[1::2]

# %%
upper_margin_OFF = list(sorted(set((l>upper_OFF)* l)))[1]
lower_margin_OFF = list(sorted(set((l<Lower_OFF)* l),reverse=True))[0]

# %%
upper_OFF = (max(l[:4]) + upper_margin_OFF)/2
Lower_OFF = (min(l[:4]) + lower_margin_OFF)/2

# %%
upper_ON,Lower_ON,upper_OFF,Lower_OFF
# Out:
# (0.49821460247039795,
#  0.496340811252594,
#  0.2657527029514313,
#  0.2630002200603485)

# %%
(np.array(l) <= upper_OFF) == (np.array(l) >= Lower_OFF)
# Out:
# array([ True,  True,  True,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False])

# %%
len(l)
# Out:
# 16

# %% [markdown]
# ## Test

# %%
n=7
b=data[n]

# %%
plt.plot(b)

# %%
c = 0
s = []
for i in b:
    c+=1
    if  i > 0.2 :
        s.append(i)

# %%
len(s)
# Out:
# 33

# %%
l = s[0::2]

# %%
(np.array(l) <= upper_ON) == (np.array(l) >= Lower_ON)
# Out:
# array([ True, False, False,  True,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
l = s[1::2]

# %%
(np.array(l) <= upper_OFF) == (np.array(l) >= Lower_OFF)
# Out:
# array([ True, False, False,  True, False, False, False, False, False,
#         True, False, False, False, False, False, False])
